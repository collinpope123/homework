# %% [markdown]
# First data set. CSV

# %%
import pandas as pd

# %%
cars = pd.read_csv ("https://perso.telecom-paristech.fr/eagan/class/igr204/data/cars.csv", ';')

# %%
print(cars)
# Out:
#                                    Car     MPG Cylinders Displacement  \
# 0                               STRING  DOUBLE       INT       DOUBLE
# 1            Chevrolet Chevelle Malibu    18.0         8        307.0
# 2                    Buick Skylark 320    15.0         8        350.0
# 3                   Plymouth Satellite    18.0         8        318.0
# 4                        AMC Rebel SST    16.0         8        304.0
# 5                          Ford Torino    17.0         8        302.0
# 6                     Ford Galaxie 500    15.0         8        429.0
# 7                     Chevrolet Impala    14.0         8        454.0
# 8                    Plymouth Fury iii    14.0         8        440.0
# 9                     Pontiac Catalina    14.0         8        455.0
# 10                  AMC Ambassador DPL    15.0         8        390.0
# 11                Citroen DS-21 Pallas       0         4        133.0
# ...

# %%
cars = cars.drop([0])

# %% [markdown]
# I am going to drop all 0's as it looks like it is random and doesn't make significant impact on my results.

# %%
cars = cars.replace('0', np.nan)

# %%
cars = cars.dropna()

# %%
cars
# Out:
#                                    Car   MPG Cylinders Displacement  \
# 1            Chevrolet Chevelle Malibu  18.0         8        307.0
# 2                    Buick Skylark 320  15.0         8        350.0
# 3                   Plymouth Satellite  18.0         8        318.0
# 4                        AMC Rebel SST  16.0         8        304.0
# 5                          Ford Torino  17.0         8        302.0
# 6                     Ford Galaxie 500  15.0         8        429.0
# 7                     Chevrolet Impala  14.0         8        454.0
# 8                    Plymouth Fury iii  14.0         8        440.0
# 9                     Pontiac Catalina  14.0         8        455.0
# 10                  AMC Ambassador DPL  15.0         8        390.0
# 16                 Dodge Challenger SE  15.0         8        383.0
# 17                  Plymouth 'Cuda 340  14.0         8        340.0
# 19               Chevrolet Monte Carlo  15.0         8        400.0
# ...

# %% [markdown]
# This is the summary statistics for cars

# %%
cars.describe()
# Out:
#                    Car   MPG Cylinders Displacement Horsepower Weight  \
# count              392   392       392          392        392    392
# unique             297   127         5           81         93    346
# top     Toyota Corolla  13.0         4        97.00      150.0  2130.
# freq                 9    20       199           21         22      4
#
#        Acceleration Model Origin
# count           392   392    392
# unique           96    13      3
# top            14.5    73     US
# freq             23    40    245

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 1 to 406
# Data columns (total 9 columns):
# Car             392 non-null object
# MPG             392 non-null object
# Cylinders       392 non-null object
# Displacement    392 non-null object
# Horsepower      392 non-null object
# Weight          392 non-null object
# Acceleration    392 non-null object
# Model           392 non-null object
# Origin          392 non-null object
# dtypes: object(9)
# memory usage: 30.6+ KB

# %%
cars.columns[cars.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
import numpy as np

# %%
sum(cars.isnull().values.ravel())
# Out:
# 0

# %% [markdown]
# Here I am changing my data into INT

# %%
cars['MPG'] = pd.to_numeric(cars['MPG'])

# %%
cars['Cylinders'] = pd.to_numeric(cars['Cylinders'])

# %%
cars['Displacement'] = pd.to_numeric(cars['Displacement'])

# %%
cars['Horsepower'] = pd.to_numeric(cars['Horsepower'])

# %%
cars['Weight'] = pd.to_numeric(cars['Weight'])

# %%
cars['Acceleration'] = pd.to_numeric(cars['Acceleration'])

# %%
cars['Model'] = pd.to_numeric(cars['Model'])

# %%
# %matplotlib inline

# %%
bbox = cars['MPG'].plot(kind="box")

# %% [markdown]
# Correlation Chart for Cars

# %%
cars.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# Cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# Displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# Horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# Weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# Acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# Model         0.580541  -0.345647     -0.369855   -0.416361 -0.309120
#
#               Acceleration     Model
# MPG               0.423329  0.580541
# Cylinders        -0.504683 -0.345647
# Displacement     -0.543800 -0.369855
# Horsepower       -0.689196 -0.416361
# Weight           -0.416839 -0.309120
# Acceleration      1.000000  0.290316
# Model             0.290316  1.000000

# %% [markdown]
# Percentile Chart

# %%
cars.describe(percentiles=[.01,.05,.95,.99])
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 1%      11.000000    3.910000     70.910000   48.000000  1771.830000
# 5%      13.000000    4.000000     85.000000   60.550000  1931.600000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 95%     37.000000    8.000000    400.000000  180.000000  4464.000000
# 99%     43.454000    8.000000    441.260000  220.450000  4951.090000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration       Model
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 1%         9.455000   70.000000
# ...

# %%
import seaborn as sns

# %% [markdown]
# This shows the correlation between Horsepower and MPG and how when Horsepower goes up MPG goes down. It is good to note it does not look linear.

# %%
sns.lmplot(x="Horsepower", y="MPG", data=cars)

# %% [markdown]
# This next plot helps us understand the normal distibution of the acceleration of cars

# %%
sns.violinplot(cars[['Acceleration']])

# %% [markdown]
# This shows what one would expect that most cars have 4 cylinders and then some have 6 and others have 8

# %%
sns.violinplot(cars[['Cylinders']])

# %%
sns.distplot(cars.Displacement, kde=False)

# %% [markdown]
# This is my JSON Dataset

# %%
import json

# %%
import requests

# %%
get_request = requests.get("https://raw.githubusercontent.com/Nexosis/sampledata/master/bostonhousing.json")

# %%
get_request.text
# Out:
# '{\r\n"columns":{\r\n        "ID": {\r\n            "dataType": "numeric",\r\n            "role": "key"\r\n        },\r\n        "NitrogenOxideConcentration": {\r\n            "dataType": "numericMeasure",\r\n            "role": "feature",\r\n            "imputation": "mean",\r\n            "aggregation": "mean"\r\n        },\r\n        "ProportionZoned": {\r\n            "dataType": "numericMeasure",\r\n            "role": "feature",\r\n            "imputation": "mean",\r\n            "aggregation": "mean"\r\n        },\r\n        "AgeOfHomes": {\r\n            "dataType": "numericMeasure",\r\n            "role": "feature",\r\n            "imputation": "mean",\r\n            "aggregation": "mean"\r\n        },\r\n        "DistanceToCenter": {\r\n            "dataType": "numericMeasure",\r\n            "role": "feature",\r\n            "imputation": "mean",\r\n            "aggregation": "mean"\r\n        },\r\n        "NitrogenOxideConcentration": {\r\n            "dataType": "numeri
# ...

# %%
conn = json.loads(get_request.text)

# %%
conn.keys()
# Out:
# dict_keys(['columns', 'data'])

# %%
conn = pd.DataFrame(conn['data'])

# %%
conn.head()
# Out:
#    AgeOfHomes  CharlesRiverDummy  DistanceToCenter  ID  IndexOfHighways  \
# 0        65.2                  0            4.0900   1                1
# 1        78.9                  0            4.9671   2                2
# 2        45.8                  0            6.0622   4                3
# 3        54.2                  0            6.0622   5                3
# 4        66.6                  0            5.5605   7                5
#
#    MedianHomeValue  NitrogenOxideConcentration  PerCapitaCrime  \
# 0            24000                       0.538         0.00632
# 1            21600                       0.469         0.02731
# 2            33400                       0.458         0.03237
# 3            36200                       0.458         0.06905
# 4            22900                       0.524         0.08829
#
#    PercentStatusPop  ProportionIndustry  ProportionZoned  PupilTeacherRatio  \
# ...

# %%
conn.describe()
# Out:
#        AgeOfHomes  CharlesRiverDummy  DistanceToCenter          ID  \
# count  333.000000         333.000000        333.000000  333.000000
# mean    68.226426           0.060060          3.709934  250.951952
# std     28.133344           0.237956          1.981123  147.859438
# min      6.000000           0.000000          1.129600    1.000000
# 25%     45.400000           0.000000          2.122400  123.000000
# 50%     76.700000           0.000000          3.092300  244.000000
# 75%     93.800000           0.000000          5.116700  377.000000
# max    100.000000           1.000000         10.710300  506.000000
#
#        IndexOfHighways  MedianHomeValue  NitrogenOxideConcentration  \
# count       333.000000       333.000000                  333.000000
# mean          9.633634     22768.768769                    0.557144
# std           8.742174      9173.468027                    0.114955
# min           1.000000      5000.000000                    0.385000
# ...

# %%
conn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 14 columns):
# AgeOfHomes                    333 non-null float64
# CharlesRiverDummy             333 non-null int64
# DistanceToCenter              333 non-null float64
# ID                            333 non-null int64
# IndexOfHighways               333 non-null int64
# MedianHomeValue               333 non-null int64
# NitrogenOxideConcentration    333 non-null float64
# PerCapitaCrime                333 non-null float64
# PercentStatusPop              333 non-null float64
# ProportionIndustry            333 non-null float64
# ProportionZoned               333 non-null float64
# PupilTeacherRatio             333 non-null float64
# RoomsPer                      333 non-null float64
# TaxRatePer                    333 non-null int64
# dtypes: float64(9), int64(5)
# memory usage: 36.5 KB

# %%
conn.corr()
# Out:
#                             AgeOfHomes  CharlesRiverDummy  DistanceToCenter  \
# AgeOfHomes                    1.000000           0.068286         -0.764208
# CharlesRiverDummy             0.068286           1.000000         -0.081834
# DistanceToCenter             -0.764208          -0.081834          1.000000
# ID                            0.257300           0.007958         -0.356461
# IndexOfHighways               0.447380           0.007714         -0.477610
# MedianHomeValue              -0.358888           0.204390          0.249422
# NitrogenOxideConcentration    0.736000           0.080275         -0.769364
# PerCapitaCrime                0.379034          -0.041195         -0.397067
# PercentStatusPop              0.588834          -0.050055         -0.505939
# ProportionIndustry            0.638378           0.037496         -0.702327
# ProportionZoned              -0.544513          -0.024442          0.637142
# ...

# %%
conn.describe(percentiles=[.01,.05,.95,.99])
# Out:
#        AgeOfHomes  CharlesRiverDummy  DistanceToCenter          ID  \
# count  333.000000         333.000000        333.000000  333.000000
# mean    68.226426           0.060060          3.709934  250.951952
# std     28.133344           0.237956          1.981123  147.859438
# min      6.000000           0.000000          1.129600    1.000000
# 1%       6.600000           0.000000          1.183224    5.640000
# 5%      17.620000           0.000000          1.502200   26.400000
# 50%     76.700000           0.000000          3.092300  244.000000
# 95%    100.000000           1.000000          7.499380  480.400000
# 99%    100.000000           1.000000          9.030800  501.360000
# max    100.000000           1.000000         10.710300  506.000000
#
#        IndexOfHighways  MedianHomeValue  NitrogenOxideConcentration  \
# count       333.000000       333.000000                  333.000000
# mean          9.633634     22768.768769                    0.557144
# ...

# %%
conn = conn.replace('0', np.nan)

# %%
conn = conn.dropna()

# %% [markdown]
# There is no missing data in this dataset

# %%
bbox = conn['NitrogenOxideConcentration'].plot(kind="box")

# %% [markdown]
# As NitrogenOxideConcentration is my main variable and it doesn't have any big outliers

# %%
sns.lmplot(x="DistanceToCenter", y="NitrogenOxideConcentration", data=conn)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# This graph shows the relationship of how far away you are to a highway and NitrogenOxideConcentration. It makes sence that the farther you are the less polution there is. It is good to note that it doesn't look linear.

# %%
sns.violinplot(conn[['NitrogenOxideConcentration']])

# %% [markdown]
# Another interesting correlation we can look at is the value of the house with how close it is the a highway

# %%
sns.lmplot(x="IndexOfHighways", y="MedianHomeValue", data=conn)

# %% [markdown]
# This is my SQL DATA

# %%
import sqlite3

# %%
conn = sqlite3.connect("/Users/collinpope/Downloads/database.sqlite")

# %%
head_df = pd.read_sql_query("select * from Iris;", conn)
head_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
head_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
head_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
head_df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
head_df = head_df.replace('0', np.nan)

# %%
head_df = head_df.dropna()

# %% [markdown]
# There are no missing values in this dataset

# %%
head_df.describe(percentiles=[.01,.05,.95,.99])
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 1%       2.490000       4.400000      2.200000       1.149000      0.100000
# 5%       8.450000       4.600000      2.345000       1.300000      0.200000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 95%    142.550000       7.255000      3.800000       6.100000      2.300000
# 99%    148.510000       7.700000      4.151000       6.700000      2.500000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
bbox = head_df['SepalLengthCm'].plot(kind="box")

# %%
bbox = head_df['SepalWidthCm'].plot(kind="box")

# %% [markdown]
# SepalWidthCm has a few outliers but it doesn't look like it matter to much

# %%
bbox = head_df['PetalLengthCm'].plot(kind="box")

# %%
bbox = head_df['PetalWidthCm'].plot(kind="box")

# %% [markdown]
# These box charts show there are not a lot of outliers. The few outliers that exist do not look abnormal and should not be a big problem

# %%
sns.lmplot(x="SepalLengthCm", y="PetalLengthCm", data=head_df)

# %% [markdown]
# This graph is interesting because it looks like there is a discontinuity between SepalLengthCm and PetalLenghtCm at about 5.5 cm

# %%
sns.violinplot(head_df[['PetalWidthCm']])

# %% [markdown]
# This chart is interesting because it shows that there isn't a normal distribution
